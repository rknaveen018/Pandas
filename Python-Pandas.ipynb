# %% [markdown]
# - Automation using Python:
# - Manipulate, Slice, Dice, Data(Structured): CSV, Excel, Txt

# %% [markdown]
# - Pandas: Data Anlysis
# - Work on Data to understand various process.

# %% [markdown]
# **Base Functionlaity**
# - Data Objects: Lists, Tuple, Dict, Sets, Strings
# - Conditions: If-Elif-Else
# - Loops: For, While
# - Functions: def
# - Comprehension: List, Dictionaries
#
# **Library: Basically a bucket(package) full of functions for specific usage/application**
#
#
# **--------------------------------------**
#
#
# **Pandas**
#
#
# Data Manipulation and processing library with python.
#
# - Data Objects: Series, DataFrame
#
# **Data Processing**
# - Inspect
# - Filter
# - Group
# - Sort
# - Merge

# %%
## Call/Import Pandas into Python

import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\SUMITH\Desktop\Data\telco_churn.csv")

# %%
df = pd.read_csv("https://query.data.world/s/442hmws6ei6qe3xfgbp6tdemtxxz7p")

# %%
s = "sumit\nshukla"

# %%
print(s)
# Out:
# sumit
# shukla

# %%
print(r"sumit\nshukla")
# Out:
# sumit\nshukla

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Inspection Over Data Frame
#
# - df.head(): Return by default top-5 rows from the DataFrame.

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %% [markdown]
# - df.tail(): Returns by default the bottom-5 rows from the DataFrame.

# %%
df.tail(2)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7041          Yes           Yes     Fiber optic             No  ...
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7041   Yes
# 7042    No
#
# [2 rows x 21 columns]

# %% [markdown]
# - df.shape: This will return the number of rows and columns in a tuple

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# - df.columns: This will return the column names from the dataframe.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# Pandas
#
# - object: String/Text
# - integer: INT
# - Float: Float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Indexing and Slicing
#
# - iloc: Indexed based method
# - loc: Name based method

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.iloc[1::2, :]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# 9     6388-TABGU    Male              0      No        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7035  8456-QDAVC    Male              0      No         No      19
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %% [markdown]
# **Using iloc, fetch rows between 1000 to 1010(including both) and all the columns in reverse direction**

# %%
df.iloc[1000:1011, ::-1]
# Out:
#      Churn TotalCharges  MonthlyCharges            PaymentMethod  \
# 1000   Yes        660.9           95.35         Electronic check
# 1001   Yes      1893.95           75.50         Electronic check
# 1002    No        284.9           69.55             Mailed check
# 1003    No       784.25           19.85             Mailed check
# 1004    No        417.7           20.00             Mailed check
# 1005    No      5016.25           95.85  Credit card (automatic)
# 1006   Yes      1612.75           90.10         Electronic check
# 1007   Yes       119.75           68.95         Electronic check
# 1008   Yes      3204.65           99.55  Credit card (automatic)
# 1009    No        485.2           20.75         Electronic check
# 1010    No       160.85           50.15             Mailed check
#
#      PaperlessBilling        Contract      StreamingMovies  \
# 1000              Yes  Month-to-month                  Yes
# 1001              Yes  Month-to-month                   No
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.loc[[2,5,9,10], ['customerID', 'gender', 'Churn']]
# Out:
#     customerID  gender Churn
# 2   3668-QPYBK    Male   Yes
# 5   9305-CDSKC  Female   Yes
# 9   6388-TABGU    Male    No
# 10  9763-GRSKD    Male    No

# %%
df.loc[[2,4,8]]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 2            No             DSL            Yes  ...               No
# 4            No     Fiber optic             No  ...               No
# 8           Yes     Fiber optic             No  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 8         Yes         Yes             Yes  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
df['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
df[ ['customerID', 'gender'] ]
# Out:
#       customerID  gender
# 0     7590-VHVEG  Female
# 1     5575-GNVDE    Male
# 2     3668-QPYBK    Male
# 3     7795-CFOCW    Male
# 4     9237-HQITU  Female
# ...          ...     ...
# 7038  6840-RESVB    Male
# 7039  2234-XADUH  Female
# 7040  4801-JZAZL  Female
# 7041  8361-LTMKD    Male
# 7042  3186-AJIEK    Male
#
# [7043 rows x 2 columns]

# %%
type(df['gender'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Filter Data On Conditions

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
a = 12

# %%
a == 12
# Out:
# True

# %%
df[df['gender'] == 'Male']
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %% [markdown]
# **Find the number of customers those who are with the company for more than 50 months**

# %%
df[ df['tenure']>50 ].shape
# Out:
# (2105, 21)

# %% [markdown]
# - and : &
# - or: |
#
#
# - and: Two values
# - &: Two boolean values

# %%
df[ (df['gender'] == 'Male') & (df['tenure']>50) ]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU   Male              0      No        Yes      62
# 12    8091-TTVAX   Male              0     Yes         No      58
# 17    9959-WOFKT   Male              0      No        Yes      71
# 28    5248-YGIJN   Male              0     Yes         No      72
# 48    7639-LIAYI   Male              0      No         No      52
# ...          ...    ...            ...     ...        ...     ...
# 6995  7164-BPTUT   Male              0      No        Yes      57
# 7007  2274-XUATA   Male              1     Yes         No      72
# 7022  7203-OYKCT   Male              0      No         No      72
# 7031  3605-JISKB   Male              1     Yes         No      55
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 9             Yes                No             DSL            Yes  ...
# ...

# %% [markdown]
# **How many customer are there who are non-churn, have monthlycharges greater than 80 and they pay on one year contract basis to the company**

# %%
df[(df['Churn'] == 'No') & (df['MonthlyCharges']>80) & (df['Contract']=='One year')].shape
# Out:
# (456, 21)

# %%
a = df[(df['Churn'] == 'No') & (df['MonthlyCharges']>80) & (df['Contract']=='One year')]

# %%
a['tenure'].mean()
# Out:
# 52.13815789473684

# %%
df[(df['Churn'] == 'No') & (df['MonthlyCharges']>80) & (df['Contract']=='One year')]['tenure'].mean()
# Out:
# 52.13815789473684

# %%
## How to find the number of unique categories or values in a columns
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %% [markdown]
# **Check if the avergae monthlycharges for non-churn, male customer who use credit card as a payment method is more or less than the average monthlycharges for churn, femal who doesn't use credit card as a payment method.**

# %%
df[ (df['Churn'] == 'No') & (df['gender'] == 'Male') & (df['PaymentMethod'] == "Credit card (automatic)")]['MonthlyCharges'].mean()
# Out:
# 63.33789237668165

# %%
df[ (df['Churn'] == 'Yes') & (df['gender'] == 'Female') & (df['PaymentMethod'] != "Credit card (automatic)")]['MonthlyCharges'].mean()
# Out:
# 74.53768564356444

# %% [markdown]
# ## Grouping and Aggregation

# %%
df.groupby('gender').agg({'tenure':'mean'})
# Out:
#            tenure
# gender
# Female  32.244553
# Male    32.495359

# %% [markdown]
# **Find the avg monthly charges and the count of customers per contract type but consider only churn customers**

# %%
df[df['Churn'] == 'Yes'].groupby("Contract").agg({'MonthlyCharges':'mean', 'customerID':'count'})
# Out:
#                 MonthlyCharges  customerID
# Contract
# Month-to-month       73.019396        1655
# One year             85.050904         166
# Two year             86.777083          48

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
df.groupby(['gender', 'Churn']).agg({'customerID':'count'})
# Out:
#               customerID
# gender Churn
# Female No           2549
#        Yes           939
# Male   No           2625
#        Yes           930

# %%
df.pivot_table(index = 'gender', columns = 'Churn', values = 'customerID', aggfunc = 'count')
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %% [markdown]
# **Find the average tenure for churn and non-churn customers under various paymentmethods**

# %%
df.pivot_table(index = 'Churn', columns = 'PaymentMethod', values = 'tenure', aggfunc = 'mean')
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# Churn
# No                             47.140747                46.101550
# Yes                            26.290698                27.521552
#
# PaymentMethod  Electronic check  Mailed check
# Churn
# No                    32.136012     25.083589
# Yes                   16.763772      8.055195

# %% [markdown]
# ## Sorting

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.sort_values(by = 'tenure', ascending = False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %% [markdown]
# **For the customer who are non-churn, are male and have monthlycharges>100, find the customerID of the customer with the maximum tenure**

# %%
df[ (df['Churn'] == 'No') & (df['gender']== 'Male') & (df['MonthlyCharges']>100)].sort_values(by = 'tenure', ascending = False)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 5995  2193-SFWQW   Male              0     Yes        Yes      72
# 6403  3258-ZKPAI   Male              0     Yes        Yes      72
# 6071  0401-WDBXM   Male              0     Yes        Yes      72
# 4620  8513-OLYGY   Male              0     Yes         No      72
# 6118  9924-JPRMC   Male              0      No         No      72
# ...          ...    ...            ...     ...        ...     ...
# 5031  8118-TJAFG   Male              0     Yes        Yes       9
# 2387  6734-GMPVK   Male              0      No         No       5
# 678   5760-IFJOZ   Male              0      No         No       3
# 1719  2081-VEYEH   Male              0      No         No       3
# 4952  7379-FNIUJ   Male              0      No         No       2
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5995          Yes            No     Fiber optic            Yes  ...
# ...

# %%
df.groupby("PaymentMethod").agg({'tenure':'mean'}).sort_values(by = 'tenure', ascending = False)
# Out:
#                               tenure
# PaymentMethod
# Bank transfer (automatic)  43.656736
# Credit card (automatic)    43.269382
# Electronic check           25.174630
# Mailed check               21.830025

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# ## Merge DataFrames

# %%
df_1 = pd.read_csv('https://query.data.world/s/4umb2ydlreimffi7yp5bwcjh4eaih3')

# %%
df_2 = pd.read_csv('https://query.data.world/s/2jvgrv4wbdx5laulijr676cwshqux5')

# %%
df_1.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df_2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
pd.merge(df_1, df_2,on = 'customerID', how = 'inner' )
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# ...

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
pd.merge(df_1, df_2, left_on = 'customerID', right_on = 'customerID', how = 'inner')
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# ...

# %% [markdown]
# - a
# - b
# - c
#
# - e = Join (a,b)
# - final = join(c,e)
